# %% [markdown]
# <a href="https://colab.research.google.com/github/vijayraju-vm/Customer-Data-Analysis/blob/main/natural_gas_price_Analysis_by_JPMorgan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Nat_Gas.csv")
df['Dates'] = pd.to_datetime(df['Dates'])
df.set_index('Dates', inplace=True)
df = df.asfreq('M')
df['Prices'] = df['Prices'].interpolate()

def estimate_price(input_date):
    input_date = pd.to_datetime(input_date)
    return float(np.interp(
        input_date.toordinal(),
        df.index.map(pd.Timestamp.toordinal),
        df['Prices']
    ))

print("Price on 2023-06-30:", estimate_price("2023-06-30"))
print("Price on 2025-06-30:", estimate_price("2025-06-30"))
# Out:
# Price on 2023-06-30: 10.9
# Price on 2025-06-30: 11.8
# /tmp/ipython-input-3398912935.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Dates'] = pd.to_datetime(df['Dates'])
# /tmp/ipython-input-3398912935.py:7: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df = df.asfreq('M')
